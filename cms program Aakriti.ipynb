# %%
#BLL


def addCustomer(id,name,age,mob):
    idlist.append(id)
    agelist.append(age)
    namelist.append(name)
    moblist.append(mob)

def searchCustomer(id):
    index=idlist.index(id)
    return index
def deleteCustomer(id):
     index=idlist.index(id)
     idlist.pop(index)
     namelist.pop(index)
     agelist.pop(index)
     moblist.pop(index)
def modifyCustomer(id,name,age,mob):
    index=idlist.index(id)
    namelist[index]=name
    agelist[index]=age
    moblist[index]=mob

def display(id,name,age,mob):
    

#PL

idlist=[]
agelist=[]
namelist=[]
moblist=[]
def showCustomer(i):
     print("Cus ID:",idlist[i],"Cust Name:",namelist[i],"Cus Age:", agelist[i],"Cus Mob:",moblist[i])
while(1):
    choice = input("Please choose the option, 1 for Add customer, 2 for Search customer,3 for Delete customer, 4 for Modify customer, 5 for Display all,6 for Exit:")
    if (choice=="1"):
           id=input("Please enter student id:")
           name= input("Please enter student name:")
           age= input("Please enter student age:")
           mob= input("Please enter student mobile number:")
           addCustomer(id,name,age,mob)
           print("Customer Added Successfully ")
    elif (choice=="2"):
            id=input("Please enter student id to search:")
            i=searchCustomer(id)
            showCustomer(i)

    elif (choice=="3"):
         id=input("Please enter student id to delete customer:")
         deleteCustomer(id)
         print("Customer Deleted Successfully")
    elif (choice=="4"):
           id=input("Please enter student id:")
           name= input("Please modify student name:")
           age= input("Please modify student age:")
           mob= input("Please modify student mobile number:")
           modifyCustomer(id,name,age,mob)
           print("Customer modified Successfully ")
    elif(choice=="5"):
       for i in range(len(idlist)):
          showCustomer(i)
    else:
       print("Thank You")
       break
# Out:
# Please choose the option, 1 for Add customer, 2 for Search customer,3 for Delete customer, 4 for Modify customer, 5 for Display all,6 for Exit:1
# Please enter student id:10
# Please enter student name:5
# Please enter student age:5
# Please enter student mobile number:5
# Customer Added Successfully
# Please choose the option, 1 for Add customer, 2 for Search customer,3 for Delete customer, 4 for Modify customer, 5 for Display all,6 for Exit:1
# Please enter student id:20
# Please enter student name:5
# Please enter student age:5
# Please enter student mobile number:5
# Customer Added Successfully
